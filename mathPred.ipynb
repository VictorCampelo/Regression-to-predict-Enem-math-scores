# %% [markdown]
# ## Imports

# %%
import pandas as pd

# %%
df_test = pd.read_csv('/content/test.csv')

# %%
columns = df_test.columns.to_list()
columns.append('NU_NOTA_MT')
columns
# Out:
# ['NU_INSCRICAO',
#  'CO_UF_RESIDENCIA',
#  'SG_UF_RESIDENCIA',
#  'NU_IDADE',
#  'TP_SEXO',
#  'TP_COR_RACA',
#  'TP_NACIONALIDADE',
#  'TP_ST_CONCLUSAO',
#  'TP_ANO_CONCLUIU',
#  'TP_ESCOLA',
#  'TP_ENSINO',
#  'IN_TREINEIRO',
#  'TP_DEPENDENCIA_ADM_ESC',
#  'IN_BAIXA_VISAO',
#  'IN_CEGUEIRA',
#  'IN_SURDEZ',
#  'IN_DISLEXIA',
#  'IN_DISCALCULIA',
#  'IN_SABATISTA',
#  'IN_GESTANTE',
#  'IN_IDOSO',
#  'TP_PRESENCA_CN',
#  'TP_PRESENCA_CH',
#  'TP_PRESENCA_LC',
#  'CO_PROVA_CN',
#  'CO_PROVA_CH',
#  'CO_PROVA_LC',
#  'CO_PROVA_MT',
#  'NU_NOTA_CN',
#  'NU_NOTA_CH',
#  'NU_NOTA_LC',
#  'TP_LINGUA',
#  'TP_STATUS_REDACAO',
#  'NU_NOTA_COMP1',
#  'NU_NOTA_COMP2',
#  'NU_NOTA_COMP3',
#  'NU_NOTA_COMP4',
#  'NU_NOTA_COMP5',
#  'NU_NOTA_REDACAO',
#  'Q001',
#  'Q002',
#  'Q006',
#  'Q024',
#  'Q025',
#  'Q026',
#  'Q027',
#  'Q047',
#  'NU_NOTA_MT']

# %%
df_train = pd.read_csv('/content/train.csv', usecols=columns)

# %%
df_train.head()
# Out:
#                                NU_INSCRICAO  CO_UF_RESIDENCIA  ... Q027  Q047
# 0  ed50e8aaa58e7a806c337585efee9ca41f1eb1ad                43  ...    H     A
# 1  2c3acac4b33ec2b195d77e7c04a2d75727fad723                23  ...  NaN     A
# 2  f4545f8ccb9ff5c8aad7d32951b3f251a26e6568                23  ...  NaN     A
# 3  3d6ec248fef899c414e77f82d5c6d2bffbeaf7fe                33  ...    F     D
# 4  bf896ac8d3ecadd6dba1dfbf50110afcbf5d3268                13  ...    F     A
#
# [5 rows x 48 columns]

# %%
df_test.head()
# Out:
#                                NU_INSCRICAO  CO_UF_RESIDENCIA  ... Q027  Q047
# 0  73ff9fcc02f0a99919906c942c2e1a1042cdcf98                41  ...    C     A
# 1  71a95f9f1b91a82c65ad94abbdf9f54e6066f968                21  ...    F     A
# 2  b38a03232f43b11c9d0788abaf060f7366053b6d                23  ...  NaN     A
# 3  70b682d9a3636be23f6120fa9d6b164eb3c6002d                15  ...  NaN     A
# 4  715494628a50142ce8cb17191cfe6d0f3cae0934                41  ...  NaN     A
#
# [5 rows x 47 columns]

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12051 entries, 0 to 12050
# Data columns (total 48 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   NU_INSCRICAO            12051 non-null  object
#  1   CO_UF_RESIDENCIA        12051 non-null  int64
#  2   SG_UF_RESIDENCIA        12051 non-null  object
#  3   NU_IDADE                12051 non-null  int64
#  4   TP_SEXO                 12051 non-null  object
#  5   TP_COR_RACA             12051 non-null  int64
#  6   TP_NACIONALIDADE        12051 non-null  int64
#  7   TP_ST_CONCLUSAO         12051 non-null  int64
#  8   TP_ANO_CONCLUIU         12051 non-null  int64
#  9   TP_ESCOLA               12051 non-null  int64
#  10  TP_ENSINO               3749 non-null   float64
#  11  IN_TREINEIRO            12051 non-null  int64
#  12  TP_DEPENDENCIA_ADM_ESC  3749 non-null   float64
#  13  IN_BAIXA_VISAO          12051 non-null  int64
# ...

# %%
df_train.describe()
# Out:
#        CO_UF_RESIDENCIA      NU_IDADE  ...  NU_NOTA_COMP5  NU_NOTA_REDACAO
# count      12051.000000  12051.000000  ...    8866.000000      8866.000000
# mean          30.731641     21.605012  ...      77.211820       528.793142
# std            9.874104      7.059885  ...      42.976175       153.849788
# min           11.000000     13.000000  ...       0.000000         0.000000
# 25%           23.000000     17.000000  ...      40.000000       440.000000
# 50%           31.000000     19.000000  ...      80.000000       540.000000
# 75%           35.000000     23.000000  ...     100.000000       600.000000
# max           53.000000     67.000000  ...     200.000000      1000.000000
#
# [8 rows x 33 columns]

# %%
drop_col = ['NU_INSCRICAO','CO_PROVA_CN', 'CO_PROVA_CH', 'CO_PROVA_LC', 'CO_PROVA_MT']

# %%
df_train.drop(drop_col, inplace=True, axis=1)

# %%
df_answer = pd.DataFrame()
df_answer['NU_INSCRICAO'] = df_test['NU_INSCRICAO']

# %%
df_test.drop(drop_col, inplace=True, axis=1)

# %%
df_train.isna().sum()
# Out:
# CO_UF_RESIDENCIA             0
# SG_UF_RESIDENCIA             0
# NU_IDADE                     0
# TP_SEXO                      0
# TP_COR_RACA                  0
# TP_NACIONALIDADE             0
# TP_ST_CONCLUSAO              0
# TP_ANO_CONCLUIU              0
# TP_ESCOLA                    0
# TP_ENSINO                 8302
# IN_TREINEIRO                 0
# TP_DEPENDENCIA_ADM_ESC    8302
# IN_BAIXA_VISAO               0
# IN_CEGUEIRA                  0
# IN_SURDEZ                    0
# IN_DISLEXIA                  0
# IN_DISCALCULIA               0
# IN_SABATISTA                 0
# IN_GESTANTE                  0
# IN_IDOSO                     0
# TP_PRESENCA_CN               0
# TP_PRESENCA_CH               0
# TP_PRESENCA_LC               0
# NU_NOTA_CN                3004
# NU_NOTA_CH                3004
# NU_NOTA_LC                3185
# NU_NOTA_MT                3185
# TP_LINGUA                    0
# TP_STATUS_REDACAO         3185
# NU_NOTA_COMP1             3185
# ...

# %%
#df_train.dropna(axis=0, subset=['NU_NOTA_MT'], inplace=True)

# %%
df_train = df_train.fillna(0)

# %%
df_test = df_test.fillna(0)

# %%
df_test.isna().sum()
# Out:
# CO_UF_RESIDENCIA          0
# SG_UF_RESIDENCIA          0
# NU_IDADE                  0
# TP_SEXO                   0
# TP_COR_RACA               0
# TP_NACIONALIDADE          0
# TP_ST_CONCLUSAO           0
# TP_ANO_CONCLUIU           0
# TP_ESCOLA                 0
# TP_ENSINO                 0
# IN_TREINEIRO              0
# TP_DEPENDENCIA_ADM_ESC    0
# IN_BAIXA_VISAO            0
# IN_CEGUEIRA               0
# IN_SURDEZ                 0
# IN_DISLEXIA               0
# IN_DISCALCULIA            0
# IN_SABATISTA              0
# IN_GESTANTE               0
# IN_IDOSO                  0
# TP_PRESENCA_CN            0
# TP_PRESENCA_CH            0
# TP_PRESENCA_LC            0
# NU_NOTA_CN                0
# NU_NOTA_CH                0
# NU_NOTA_LC                0
# TP_LINGUA                 0
# TP_STATUS_REDACAO         0
# NU_NOTA_COMP1             0
# NU_NOTA_COMP2             0
# NU_NOTA_COMP3             0
# NU_NOTA_COMP4             0
# NU_NOTA_COMP5             0
# ...

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12051 entries, 0 to 12050
# Data columns (total 43 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   CO_UF_RESIDENCIA        12051 non-null  int64
#  1   SG_UF_RESIDENCIA        12051 non-null  object
#  2   NU_IDADE                12051 non-null  int64
#  3   TP_SEXO                 12051 non-null  object
#  4   TP_COR_RACA             12051 non-null  int64
#  5   TP_NACIONALIDADE        12051 non-null  int64
#  6   TP_ST_CONCLUSAO         12051 non-null  int64
#  7   TP_ANO_CONCLUIU         12051 non-null  int64
#  8   TP_ESCOLA               12051 non-null  int64
#  9   TP_ENSINO               12051 non-null  float64
#  10  IN_TREINEIRO            12051 non-null  int64
#  11  TP_DEPENDENCIA_ADM_ESC  12051 non-null  float64
#  12  IN_BAIXA_VISAO          12051 non-null  int64
#  13  IN_CEGUEIRA             12051 non-null  int64
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# Label encode ord_1 feature
objList = df_train.select_dtypes(include = "object").columns
le = LabelEncoder()
df_train[objList] = df_train[objList].astype(str).apply(le.fit_transform)
# Print sample of dataset
df_train.head()
# Out:
#    CO_UF_RESIDENCIA  SG_UF_RESIDENCIA  NU_IDADE  ...  Q026  Q027  Q047
# 0                43                22        24  ...     3     8     1
# 1                23                 5        17  ...     1     0     1
# 2                23                 5        21  ...     1     0     1
# 3                33                18        25  ...     3     6     4
# 4                13                 2        28  ...     2     6     1
#
# [5 rows x 43 columns]

# %%
# Label encode ord_1 feature
objList = df_test.select_dtypes(include = "object").columns
le = LabelEncoder()
df_test[objList] = df_test[objList].astype(str).apply(le.fit_transform)
# Print sample of dataset
df_test.head()
# Out:
#    CO_UF_RESIDENCIA  SG_UF_RESIDENCIA  NU_IDADE  ...  Q026  Q027  Q047
# 0                41                17        22  ...     2     3     0
# 1                21                 9        26  ...     1     6     0
# 2                23                 5        21  ...     0     0     0
# 3                15                13        27  ...     0     0     0
# 4                41                17        18  ...     0     0     0
#
# [5 rows x 42 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats
y = df_train['NU_NOTA_MT']
plt.figure(1); plt.title('Johnson SU')
sns.distplot(y, kde=False, fit=stats.johnsonsu)
plt.figure(2); plt.title('Normal')
sns.distplot(y, kde=False, fit=stats.norm)
plt.figure(3); plt.title('Log Normal')
sns.distplot(y, kde=False, fit=stats.lognorm)
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
from sklearn.preprocessing import RobustScaler
cols = df_train.columns.to_list()
cols.remove('NU_NOTA_MT')
scaler1 = RobustScaler()
df_train[cols] = scaler1.fit_transform(df_train[cols])
df_train
# Out:
#        CO_UF_RESIDENCIA  SG_UF_RESIDENCIA  NU_IDADE  ...  Q026  Q027  Q047
# 0              1.000000          0.642857  0.833333  ...   2.0  2.00   0.0
# 1             -0.666667         -0.571429 -0.333333  ...   0.0  0.00   0.0
# 2             -0.666667         -0.571429  0.333333  ...   0.0  0.00   0.0
# 3              0.166667          0.357143  1.000000  ...   2.0  1.50   3.0
# 4             -1.500000         -0.785714  1.500000  ...   1.0  1.50   0.0
# ...                 ...               ...       ...  ...   ...   ...   ...
# 12046         -0.666667         -0.571429 -0.333333  ...   0.0  0.00   0.0
# 12047          0.333333          0.857143 -0.500000  ...   0.0  0.00   0.0
# 12048         -0.833333         -0.285714 -0.166667  ...   0.0  0.00   0.0
# 12049         -1.333333          0.000000  0.000000  ...   1.0  0.25   0.0
# 12050         -0.666667         -0.571429  0.666667  ...  -1.0  0.00  -1.0
#
# [12051 rows x 43 columns]

# %%
cols = df_test.columns.to_list()

scaler1 = RobustScaler()
df_test[cols] = scaler1.fit_transform(df_test[cols])
df_test
# Out:
#       CO_UF_RESIDENCIA  SG_UF_RESIDENCIA  NU_IDADE  ...  Q026  Q027  Q047
# 0             0.833333          0.307692  0.500000  ...   2.0  0.75   0.0
# 1            -0.833333         -0.307692  1.166667  ...   1.0  1.50   0.0
# 2            -0.666667         -0.615385  0.333333  ...   0.0  0.00   0.0
# 3            -1.333333          0.000000  1.333333  ...   0.0  0.00   0.0
# 4             0.833333          0.307692 -0.166667  ...   0.0  0.00   0.0
# ...                ...               ...       ...  ...   ...   ...   ...
# 4571          0.833333          0.307692 -0.333333  ...   0.0  0.00   0.0
# 4572          0.333333          0.923077 -0.333333  ...   0.0  0.00   0.0
# 4573          0.333333          0.923077  0.000000  ...   0.0  0.00   3.0
# 4574          1.750000         -0.384615 -0.333333  ...   0.0  0.00   0.0
# 4575          0.166667          0.384615  1.833333  ...   1.0  0.50   0.0
#
# [4576 rows x 42 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(30, 15))
sns.heatmap(df_train.corr(),
            annot = True,
            fmt = '.2f',
            cmap='Blues', )
plt.title('Correlation')
plt.show()

# %%
#Correlation with output variable
cor = df_train.corr()
cor_target = abs(cor['NU_NOTA_MT'])
#Selecting highly correlated features
relevant_features = cor_target[cor_target>0.5]
relevant_features
# Out:
# TP_PRESENCA_CN       0.876588
# TP_PRESENCA_CH       0.876588
# TP_PRESENCA_LC       0.923178
# NU_NOTA_CN           0.909102
# NU_NOTA_CH           0.905454
# NU_NOTA_LC           0.943994
# NU_NOTA_MT           1.000000
# TP_STATUS_REDACAO    0.562723
# NU_NOTA_COMP1        0.883810
# NU_NOTA_COMP2        0.863338
# NU_NOTA_COMP3        0.855975
# NU_NOTA_COMP4        0.867982
# NU_NOTA_COMP5        0.724278
# NU_NOTA_REDACAO      0.877104
# Name: NU_NOTA_MT, dtype: float64

# %%
from sklearn.model_selection import train_test_split

y = df_train['NU_NOTA_MT']
x = df_train.drop(['NU_NOTA_MT'], axis=1)
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.4, random_state=42)

# %%
from sklearn.linear_model import ElasticNet, Lasso,  BayesianRidge, LassoLarsIC
from sklearn.ensemble import RandomForestRegressor,  GradientBoostingRegressor
from sklearn.kernel_ridge import KernelRidge
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import RobustScaler
from sklearn.base import BaseEstimator, TransformerMixin, RegressorMixin, clone
from sklearn.model_selection import KFold, cross_val_score, train_test_split
from sklearn.metrics import mean_squared_error
import xgboost as xgb
import lightgbm as lgb

# %%
import numpy as np
from sklearn import linear_model
from sklearn.metrics import explained_variance_score, max_error, mean_absolute_error, r2_score, plot_confusion_matrix

clf = linear_model.LinearRegression()
clf.fit(x_train, y_train)
pred = clf.predict(x_test)
print(clf.score(x_train, y_train))
print(explained_variance_score(y_test, pred))
print(max_error(y_test, pred))
print(mean_absolute_error(y_test, pred))
print(r2_score(y_test, pred))
# Out:
# 0.9165462712842668
# 0.9142976261356991
# 509.8682150830623
# 47.787771237676836
# 0.9142002974995804

# %%
clf = linear_model.RidgeCV(cv=5)
clf.fit(x_train, y_train)
pred = clf.predict(x_test)
print("Score: "+ str(clf.score(x_train, y_train)))

print(max_error(y_test, pred))
print(mean_absolute_error(y_test, pred))
print(r2_score(y_test, pred))
# Out:
# Score: 0.9162587532832268
# 462.91986063226454
# 47.97940306298682
# 0.9148802892088792

# %%
clf = linear_model.LassoCV()
clf.fit(x_train, y_train)
pred = clf.predict(x_test)
print("Score: "+ str(clf.score(x_train, y_train)))

print(max_error(y_test, pred))
print(mean_absolute_error(y_test, pred))
print(r2_score(y_test, pred))
# Out:
# Score: 0.915482349930301
# 405.3594832346601
# 48.173565459872634
# 0.9154595826418884

# %%
kfolds = KFold(n_splits=10, shuffle=True, random_state=42)

# setup models    
alphas_alt = [14.5, 14.6, 14.7, 14.8, 14.9, 15, 15.1, 15.2, 15.3, 15.4, 15.5]
alphas2 = [5e-05, 0.0001, 0.0002, 0.0003, 0.0004, 0.0005, 0.0006, 0.0007, 0.0008]
e_alphas = [0.0001, 0.0002, 0.0003, 0.0004, 0.0005, 0.0006, 0.0007]
e_l1ratio = [0.8, 0.85, 0.9, 0.95, 0.99, 1]

ridge = make_pipeline(RobustScaler(),
                      linear_model.RidgeCV(alphas=alphas_alt, cv=kfolds))

lasso = make_pipeline(RobustScaler(),
                      linear_model.LassoCV(max_iter=1e7, alphas=alphas2,
                              random_state=42, cv=kfolds))

elasticnet = make_pipeline(RobustScaler(),
                           linear_model.ElasticNetCV(max_iter=1e7, alphas=e_alphas,
                                        cv=kfolds, l1_ratio=e_l1ratio))
                                        
gbr = GradientBoostingRegressor(n_estimators=100, learning_rate=0.05,
                                   max_depth=4, max_features='sqrt',
                                   min_samples_leaf=15, min_samples_split=10, 
                                   loss='huber', random_state =42)
                                   

lightgbm = lgb.LGBMRegressor(objective='regression', 
                                       num_leaves=4,
                                       learning_rate=0.01, 
                                       n_estimators=100,
                                       max_bin=200, 
                                       bagging_fraction=0.75,
                                       bagging_freq=5, 
                                       bagging_seed=7,
                                       feature_fraction=0.2,
                                       feature_fraction_seed=7,
                                       verbose=-1,
                                       #min_data_in_leaf=2,
                                       #min_sum_hessian_in_leaf=11
                                       )
                                       

xgboost = xgb.XGBRegressor(learning_rate=0.01, n_estimators=100,
                                     max_depth=3, min_child_weight=0,
                                     gamma=0, subsample=0.7,
                                     colsample_bytree=0.7,
                                     objective='reg:linear', nthread=-1,
                                     scale_pos_weight=1, seed=27,
                                     reg_alpha=0.00006)

# %%
ridge.fit(x_train, y_train)
pred = ridge.predict(x_test)
print("Score: "+ str(ridge.score(x_train, y_train)))

print(max_error(y_test, pred))
print(mean_absolute_error(y_test, pred))
print(r2_score(y_test, pred))
# Out:
# Score: 0.9158109420308438
# 433.4101419786752
# 48.308507037496625
# 0.9149373416871761

# %%
lasso.fit(x_train, y_train)
pred = lasso.predict(x_test)
print("Score: "+ str(lasso.score(x_train, y_train)))

print(max_error(y_test, pred))
print(mean_absolute_error(y_test, pred))
print(r2_score(y_test, pred))
# Out:
# Score: 0.9165458652491508
# 509.5292978496304
# 47.78120243358849
# 0.9142184761637457

# %%
elasticnet.fit(x_train, y_train)
pred = elasticnet.predict(x_test)
print("Score: "+ str(elasticnet.score(x_train, y_train)))

print(max_error(y_test, pred))
print(mean_absolute_error(y_test, pred))
print(r2_score(y_test, pred))
# Out:
# Score: 0.9165274030499818
# 501.3238707392443
# 47.79651861285702
# 0.9143844834943587

# %%
gbr.fit(x_train, y_train)
pred = gbr.predict(x_test)
print("Score: "+ str(gbr.score(x_train, y_train)))

print(max_error(y_test, pred))
print(mean_absolute_error(y_test, pred))
print(r2_score(y_test, pred))
# Out:
# Score: 0.9294104799310793
# 430.79482964894896
# 42.89683096954761
# 0.9250143064596608

# %%
lightgbm.fit(x_train, y_train)
pred = lightgbm.predict(x_test)
print("Score: "+ str(lightgbm.score(x_train, y_train)))

print(max_error(y_test, pred))
print(mean_absolute_error(y_test, pred))
print(r2_score(y_test, pred))
# Out:
# Score: 0.7713970833232899
# 403.87643580872384
# 87.4630807891945
# 0.7780997349641666

# %%
xgboost.fit(x_train, y_train)
pred = xgboost.predict(x_test)
print("Score: "+ str(xgboost.score(x_train, y_train)))

print(max_error(y_test, pred))
print(mean_absolute_error(y_test, pred))
print("r2: "+ str(r2_score(y_test, pred)))
# Out:
# [19:28:28] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Score: 0.477741772181809
# 490.2390441894531
# 128.04920058172289
# r2: 0.48268692622314946

# %%
import numpy as np
import pandas as pd
from sklearn import preprocessing
import xgboost as xgb
from xgboost.sklearn import XGBRegressor
import datetime
from sklearn.model_selection import GridSearchCV

# Various hyper-parameters to tune
xgb1 = XGBRegressor()
parameters = {'nthread':[4], #when use hyperthread, xgboost may become slower
              'objective':['reg:linear'],
              'learning_rate': [.03, .05, .07], #so called `eta` value
              'max_depth': [3, 4, 5],
              'min_child_weight': [4],
              'silent': [1],
              'colsample_bytree': [0.5, 0.7],
              'n_estimators': [50, 100],
              'reg_lambda':[1e-5, 1e-2, 0.45],
              'subsample':[0.5,0.6,0.7] }

xgb_grid = GridSearchCV(xgb1,
                        parameters, 
                        n_jobs=-1,
                        verbose=True)

xgb_grid.fit(x_train,y_train)

print(xgb_grid.best_score_)
print(xgb_grid.best_params_)
# Out:
# Fitting 5 folds for each of 324 candidates, totalling 1620 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  46 tasks      | elapsed:   14.5s
# [Parallel(n_jobs=-1)]: Done 196 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=-1)]: Done 446 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=-1)]: Done 796 tasks      | elapsed:  6.7min
# [Parallel(n_jobs=-1)]: Done 1246 tasks      | elapsed: 11.0min
# [Parallel(n_jobs=-1)]: Done 1620 out of 1620 | elapsed: 14.9min finished
# 0.9265852839582198
# {'colsample_bytree': 0.7, 'learning_rate': 0.05, 'max_depth': 5, 'min_child_weight': 4, 'n_estimators': 100, 'nthread': 4, 'objective': 'reg:linear', 'reg_lambda': 0.45, 'silent': 1, 'subsample': 0.7}

# %%
best_xgb_model = XGBRegressor(
    colsample_bytree= 0.7, learning_rate= 0.05, 
    max_depth=4, min_child_weight= 4, n_estimators= 100, 
    nthread=-1, objective= 'reg:linear', 
    reg_lambda= 0.45, silent=1, subsample= 0.5)
best_xgb_model.fit(x_train,y_train)

pred = best_xgb_model.predict(x_test)
print("Score: "+ str(best_xgb_model.score(x_train, y_train)))

print(max_error(y_test, pred))
print(mean_absolute_error(y_test, pred))
print(r2_score(y_test, pred))
# Out:
# Score: 0.9341502533092576
# 349.5758911132813
# 41.77728614077186
# 0.9279483931270546

# %%
df_answer['NU_NOTA_MT'] = pd.DataFrame(data=np.around(best_xgb_model.predict(df_test),2))

# %%
df_answer.head()
# Out:
#                                NU_INSCRICAO  NU_NOTA_MT
# 0  73ff9fcc02f0a99919906c942c2e1a1042cdcf98  424.250000
# 1  71a95f9f1b91a82c65ad94abbdf9f54e6066f968  447.890015
# 2  b38a03232f43b11c9d0788abaf060f7366053b6d  607.099976
# 3  70b682d9a3636be23f6120fa9d6b164eb3c6002d    0.310000
# 4  715494628a50142ce8cb17191cfe6d0f3cae0934  552.159973

# %%
df_answer.to_csv('/content/answer.csv', index=False, header=True)

# %%
from sklearn.feature_selection import SelectKBest, SelectPercentile, f_regression, f_classif
from sklearn.metrics import mean_absolute_error
from sklearn.ensemble import RandomForestRegressor
import warnings
warnings.filterwarnings("ignore")

k_vs_score = []

for k in range(2,42,2):
  selector = SelectKBest(score_func=f_regression, k=k)

  Xtrain2 = selector.fit_transform(x_train, y_train)
  Xval2 = selector.transform(x_test)

  mdl = XGBRegressor(
    colsample_bytree= 0.7, learning_rate= 0.05, 
    max_depth=4, min_child_weight= 4, n_estimators= 100, 
    nthread=-1, objective= 'reg:linear', 
    reg_lambda= 0.45, silent=1, subsample= 0.5)
  
  best_xgb_model.fit(x_train,y_train)

  mdl.fit(Xtrain2, y_train)

  p = mdl.predict(Xval2)

  score = mean_absolute_error(y_test, p)
  print("k = {} - MAE = {}".format(k, score))

  k_vs_score.append(score)
# Out:
# k = 2 - MAE = 47.791492635406065
# k = 4 - MAE = 43.006085648965204
# k = 6 - MAE = 42.841518897004846
# k = 8 - MAE = 42.918565346852944
# k = 10 - MAE = 42.79047794466913
# k = 12 - MAE = 42.87493902161591
# k = 14 - MAE = 42.84481823221822
# k = 16 - MAE = 42.38590528857186
# k = 18 - MAE = 42.47959009726323
# k = 20 - MAE = 42.45402639293493
# k = 22 - MAE = 42.31329358228013
# k = 24 - MAE = 42.335807697533376
# k = 26 - MAE = 42.22107496327865
# k = 28 - MAE = 42.194928348472416
# k = 30 - MAE = 41.8760135364666
# k = 32 - MAE = 41.76593880599971
# k = 34 - MAE = 41.72972472421338
# k = 36 - MAE = 41.768445426940275
# k = 38 - MAE = 41.70925714688241
# k = 40 - MAE = 41.785604624308334

# %%
pd.Series(k_vs_score, index=range(2,42,2)).plot(figsize=(10,7))

# %%
selector = SelectKBest(score_func=f_regression, k=40)
selector.fit(x_train, y_train)
# Out:
# SelectKBest(k=40, score_func=<function f_regression at 0x7f2fe7e17d08>)

# %%
mask = selector.get_support()
cols = x_test.columns[mask].to_list()

# %%
pd.Series(selector.scores_, index=x_train.columns).sort_values().head().plot.barh()

# %%
df_test = df_test[cols]
cols.append('NU_NOTA_MT')
df_train = df_train[cols]

# %%
import xgboost as xgb

y = df_train['NU_NOTA_MT']
x = df_train.drop(['NU_NOTA_MT'], axis=1)
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.4, random_state=42)


dtrain = xgb.DMatrix(X_train, label=y_train)
dtest = xgb.DMatrix(X_test, label=y_test)
dpred = xgb.DMatrix(df_test)

# %%
# "Learn" the mean from the training data
mean_train = np.mean(y_train)
# Get predictions on the test set
baseline_predictions = np.ones(y_test.shape) * mean_train
# Compute MAE
mae_baseline = mean_absolute_error(y_test, baseline_predictions)
print("Baseline MAE is {:.2f}".format(mae_baseline))
# Out:
# Baseline MAE is 185.61

# %%
params = {
    # Parameters that we are going to tune.
    'max_depth':6,
    'min_child_weight': 1,
    'eta':.3,
    'subsample': 1,
    'colsample_bytree': 1,
    # Other parameters
    'objective':'reg:linear',
}

params['eval_metric'] = "mae"
num_boost_round = 999

model = xgb.train(
    params,
    dtrain,
    num_boost_round=num_boost_round,
    evals=[(dtest, "Test")],
    early_stopping_rounds=10
)

print("Best MAE: {:.2f} with {} rounds".format(
                 model.best_score,
                 model.best_iteration+1))
# Out:
# [19:53:50] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	Test-mae:246.635
# Will train until Test-mae hasn't improved in 10 rounds.
# [1]	Test-mae:172.124
# [2]	Test-mae:120.163
# [3]	Test-mae:84.59
# [4]	Test-mae:62.6721
# [5]	Test-mae:51.188
# [6]	Test-mae:45.7867
# [7]	Test-mae:43.3524
# [8]	Test-mae:42.2932
# [9]	Test-mae:41.9455
# [10]	Test-mae:41.8163
# [11]	Test-mae:41.9246
# [12]	Test-mae:42.0582
# [13]	Test-mae:42.2392
# [14]	Test-mae:42.2736
# [15]	Test-mae:42.4432
# [16]	Test-mae:42.5965
# [17]	Test-mae:42.6978
# [18]	Test-mae:42.7312
# [19]	Test-mae:42.8507
# [20]	Test-mae:42.887
# Stopping. Best iteration:
# [10]	Test-mae:41.8163
#
# Best MAE: 41.82 with 11 rounds

# %%
cv_results = xgb.cv(
    params,
    dtrain,
    num_boost_round=num_boost_round,
    seed=42,
    nfold=5,
    metrics={'mae'},
    early_stopping_rounds=10
)

print(cv_results['test-mae-mean'].min())
# Out:
# [19:55:10] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:55:10] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:55:10] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:55:10] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:55:10] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 42.6904412

# %%
warnings.filterwarnings("ignore")
# You can try wider intervals with a larger step between
# each value and then narrow it down. Here after several
# iteration I found that the optimal value was in the
# following ranges.
gridsearch_params = [
    (max_depth, min_child_weight)
    for max_depth in range(9,12)
    for min_child_weight in range(5,8)
]

# Define initial best params and MAE
min_mae = float("Inf")
best_params = None
for max_depth, min_child_weight in gridsearch_params:
    print("CV with max_depth={}, min_child_weight={}".format(
                             max_depth,
                             min_child_weight))
    # Update our parameters
    params['max_depth'] = max_depth
    params['min_child_weight'] = min_child_weight
    # Run CV
    cv_results = xgb.cv(
        params,
        dtrain,
        num_boost_round=num_boost_round,
        seed=42,
        nfold=5,
        metrics={'mae'},
        early_stopping_rounds=10
    )
    # Update best MAE
    mean_mae = cv_results['test-mae-mean'].min()
    boost_rounds = cv_results['test-mae-mean'].argmin()
    print("\tMAE {} for {} rounds".format(mean_mae, boost_rounds))
    if mean_mae < min_mae:
        min_mae = mean_mae
        best_params = (max_depth,min_child_weight)
print("Best params: {}, {}, MAE: {}".format(best_params[0], best_params[1], min_mae))
# Out:
# CV with max_depth=9, min_child_weight=5
# [19:56:40] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:56:40] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:56:40] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:56:40] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:56:40] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 43.5096134 for 10 rounds
# CV with max_depth=9, min_child_weight=6
# [19:56:42] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ...

# %%
params['max_depth'] = 9
params['min_child_weight'] = 6

# %%
gridsearch_params = [
    (subsample, colsample)
    for subsample in [i/10. for i in range(7,11)]
    for colsample in [i/10. for i in range(7,11)]
]

min_mae = float("Inf")
best_params = None
# We start by the largest values and go down to the smallest
for subsample, colsample in reversed(gridsearch_params):
    print("CV with subsample={}, colsample={}".format(
                             subsample,
                             colsample))
    # We update our parameters
    params['subsample'] = subsample
    params['colsample_bytree'] = colsample
    # Run CV
    cv_results = xgb.cv(
        params,
        dtrain,
        num_boost_round=num_boost_round,
        seed=42,
        nfold=5,
        metrics={'mae'},
        early_stopping_rounds=10
    )
    # Update best score
    mean_mae = cv_results['test-mae-mean'].min()
    boost_rounds = cv_results['test-mae-mean'].argmin()
    print("\tMAE {} for {} rounds".format(mean_mae, boost_rounds))
    if mean_mae < min_mae:
        min_mae = mean_mae
        best_params = (subsample,colsample)
print("Best params: {}, {}, MAE: {}".format(best_params[0], best_params[1], min_mae))
# Out:
# CV with subsample=1.0, colsample=1.0
# [19:58:40] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:58:40] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:58:40] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:58:40] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:58:40] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 43.299754400000005 for 11 rounds
# CV with subsample=1.0, colsample=0.9
# [19:58:42] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ...

# %%
params['subsample'] = .9
params['colsample_bytree'] = 1.

# %%
# %time
# This can take some time…
min_mae = float("Inf")
best_params = None
for eta in [.3, .2, .1, .05, .01, .005]:
    print("CV with eta={}".format(eta))
    # We update our parameters
    params['eta'] = eta
    # Run and time CV
    # %time 
    cv_results = xgb.cv(
            params,
            dtrain,
            num_boost_round=num_boost_round,
            seed=42,
            nfold=5,
            metrics=['mae'],
            early_stopping_rounds=10
          )
    # Update best score
    mean_mae = cv_results['test-mae-mean'].min()
    boost_rounds = cv_results['test-mae-mean'].argmin()
    print("\tMAE {} for {} rounds\n".format(mean_mae, boost_rounds))
    if mean_mae < min_mae:
        min_mae = mean_mae
        best_params = eta
print("Best params: {}, MAE: {}".format(best_params, min_mae))
# Out:
# CPU times: user 3 µs, sys: 1 µs, total: 4 µs
# Wall time: 6.91 µs
# CV with eta=0.3
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 5.72 µs
# [20:06:11] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:06:11] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:06:11] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:06:11] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:06:12] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 	MAE 43.1472344 for 10 rounds
#
# CV with eta=0.2
# CPU times: user 2 µs, sys: 0 ns, total: 2 µs
# Wall time: 5.72 µs
# ...

# %%
params['eta'] = .005

# %%
model = xgb.train(
    params,
    dtrain,
    num_boost_round=num_boost_round,
    evals=[(dtest, "Test")],
    early_stopping_rounds=10
)

print("Best MAE: {:.2f} in {} rounds".format(model.best_score, model.best_iteration+1))
# Out:
# [20:09:12] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	Test-mae:351.549
# Will train until Test-mae hasn't improved in 10 rounds.
# [1]	Test-mae:349.781
# [2]	Test-mae:348.024
# [3]	Test-mae:346.273
# [4]	Test-mae:344.532
# [5]	Test-mae:342.802
# [6]	Test-mae:341.076
# [7]	Test-mae:339.358
# [8]	Test-mae:337.652
# [9]	Test-mae:335.951
# [10]	Test-mae:334.264
# [11]	Test-mae:332.583
# [12]	Test-mae:330.91
# [13]	Test-mae:329.246
# [14]	Test-mae:327.591
# [15]	Test-mae:325.945
# [16]	Test-mae:324.307
# [17]	Test-mae:322.677
# [18]	Test-mae:321.056
# [19]	Test-mae:319.437
# [20]	Test-mae:317.832
# [21]	Test-mae:316.234
# [22]	Test-mae:314.645
# [23]	Test-mae:313.063
# [24]	Test-mae:311.493
# [25]	Test-mae:309.925
# [26]	Test-mae:308.369
# [27]	Test-mae:306.819
# [28]	Test-mae:305.276
# [29]	Test-mae:303.744
# [30]	Test-mae:302.215
# [31]	Test-mae:300.695
# [32]	Test-mae:299.184
# [33]	Test-mae:297.677
# ...

# %%
num_boost_round = model.best_iteration + 1
best_model = xgb.train(
    params,
    dtrain,
    num_boost_round=num_boost_round,
    evals=[(dtest, "Test")]
)
mean_absolute_error(best_model.predict(dtest), y_test)
# Out:
# [20:10:14] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	Test-mae:351.549
# [1]	Test-mae:349.781
# [2]	Test-mae:348.024
# [3]	Test-mae:346.273
# [4]	Test-mae:344.532
# [5]	Test-mae:342.802
# [6]	Test-mae:341.076
# [7]	Test-mae:339.358
# [8]	Test-mae:337.652
# [9]	Test-mae:335.951
# [10]	Test-mae:334.264
# [11]	Test-mae:332.583
# [12]	Test-mae:330.91
# [13]	Test-mae:329.246
# [14]	Test-mae:327.591
# [15]	Test-mae:325.945
# [16]	Test-mae:324.307
# [17]	Test-mae:322.677
# [18]	Test-mae:321.056
# [19]	Test-mae:319.437
# [20]	Test-mae:317.832
# [21]	Test-mae:316.234
# [22]	Test-mae:314.645
# [23]	Test-mae:313.063
# [24]	Test-mae:311.493
# [25]	Test-mae:309.925
# [26]	Test-mae:308.369
# [27]	Test-mae:306.819
# [28]	Test-mae:305.276
# [29]	Test-mae:303.744
# [30]	Test-mae:302.215
# [31]	Test-mae:300.695
# [32]	Test-mae:299.184
# [33]	Test-mae:297.677
# [34]	Test-mae:296.182
# [35]	Test-mae:294.692
# ...

# %%
df_answer['NU_NOTA_MT'] = pd.DataFrame(data=np.around(best_model.predict(dpred),2))

# %%
df_answer.to_csv('/content/answer.csv', index=False, header=True)

# %%
df_answer.head()
# Out:
#                                NU_INSCRICAO  NU_NOTA_MT
# 0  73ff9fcc02f0a99919906c942c2e1a1042cdcf98  424.470001
# 1  71a95f9f1b91a82c65ad94abbdf9f54e6066f968  442.010010
# 2  b38a03232f43b11c9d0788abaf060f7366053b6d  599.809998
# 3  70b682d9a3636be23f6120fa9d6b164eb3c6002d    0.010000
# 4  715494628a50142ce8cb17191cfe6d0f3cae0934  545.030029
